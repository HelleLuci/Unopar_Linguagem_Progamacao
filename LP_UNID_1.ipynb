# %% [markdown]
# <a href="https://colab.research.google.com/github/HelleLuci/Unopar_Linguagem_Progamacao/blob/main/LP_UNID_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unid. 1_ Aula 1

# %%
# 1.Primeiro print da matéria
print("hello world")

# %%
# 2.Criando variáveis de tipos difrentes
x = 10
nome = 'Hellen'
nota = 8.5
fez_inscricao = True

# %%
print(x)
print(nome)
print(nota)
print(fez_inscricao)

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))

# %%
nome = input("Digite seu nome: ")

# %%
print(f"Olá {nome}, bem vinda à matéria de programação!")

# %%
nota_1 = int(input("Digite a nota: "))
nota_2 = int(input("Digite a nota: "))
nota_3 = int(input("Digite a nota: "))
nota_4 = int(input("Digite a nota: "))

# %%
media = (nota_1+nota_2+nota_3+nota_4)/4

# %%
print(media)

# %%
if media >= 6:
  situacao = "Aprovado"
else:
    situacao = "Reprovado"

# %%
print(situacao)

# %% [markdown]
# ## Unid. 1- AULA 2

# %%
print(10>5)
print(10==10)
print(10!=5)

# %%
# Guardando informações
idade = 5
e_maior_de_idade = idade >= 18
print(e_maior_de_idade)

# %%
print(True and True)

# %%
print(True and False)

# %%
idade = int(input("Digite sua idade: "))
if idade <= 18:
  print("Menor de idade!")
elif idade >= 18 and idade < 65:
  print("Adulto.")
else:
  print("Idoso.")

# %%
# Desafio do potótipo para o cinema
quantidadeDeIngressos = 0

if quantidadeDeIngressos > 0:

  idade = int(input("Digite a sua idade: "))

  if idade < 18:
    print("Recomendamos o filme Lillo e Stich, ingressos disponíveis!")
  elif idade >= 18 and idade < 20:
    print("Recomendamos o filme de ação na sala 1, ingressos disoníveis!")
  else:
    print("recomendamos o filme de terror na sala 2, ingressos disponíves!")

else:
  print("Desculpe. Sem ingressos disponíveis")

# %% [markdown]
# # Unid. 1_Aula 3

# %%
#mudando código exemplo para a saída combinar texto e item da lista
numeros = [1, 2, 3, 4, 5, 6]

for num in numeros:

  #usando f-strig para exibir a variável
  print(f"Camisa: {num}")

# %%
camisetas = ["Azul", "Amarela", "Preta", "Vermelha"]

#testando função enumerate(): que dá a contagem e o item
for i, cor in enumerate(camisetas, start=1):
  print(f"Camiseta {i} : {cor}")

# %%
# desafio classificador de filmes, com a correção

filmes = ["Filme 1", "Filme 2", "Filme 3", "Filme 4", "Filme 5"]

#criando os prints iniciais para informar o usuário
print("Bem vindo à classificação de filmes.")
print("Você tem cinco filmes para classificar!")
print("Digite '0' a qualquer momento para sair.\n") #\n pula uma linha

# criando lanço for para iterar na lista, corrigindo variavel
for filme in filmes:
  # tentando capturar entrada como inteiro
  classificacao= int(input(f"Como você classifica o filme '{filme}', ou '0' para parar: "))

  # condicionais para controle de entradas e fluxo
  if classificacao == 0:
    print("Que pena, volte sempre.")
    break
  if classificacao < 1 or classificacao > 5:
    print("Classificação inválida")
  else:
    print(f"Você classificou o '{filme}' com {classificacao}")
    print("Obrigado")

# %% [markdown]
# #Unid. 1_Aula 4 ❣

# %%
# apesar do professor conseguir chamar a variavel anterior numeros, o ambiente identificou como não definida
# definindo varável numeroNatural para testar função len()

numeroNatural = [1, 2, 3, 4, 5, 6]

comprimento = len(numeroNatural)

print(comprimento)

# %%
# criand uma função de soma
def soma (a, b):
  resultado = a + b
  return resultado
resultado_soma = soma (5, 2) # armazenando em nova variável

# %%
resultado_soma # colb mostra o resultado de uma variável mesmo sem print

# %%
# criando função para definir se é par
def eh_par (numero):
  if numero % 2 == 0:
    return True
  else:
    return False

# chamando a função e criando a variavel numero para ela
numero = 75
teste = eh_par(numero)
print(teste) #fazendo o print de teste e vendo o retorno funcionar

# %%
# criar função lambda
# lambda_exp = lambda parametro: expressão

media = 7.36666688

# recebe a variável como parametro
arredondar_media = lambda media: round(media,2)

#guardar valor de forma  organizada
media_arredondada = arredondar_media(media)
print(media_arredondada)

# %%
# testando desafio dos numeros primos
# primo é divisivel apenas por um e ele mesmo
# teste numero 4
def eh_primo (numero):
  if numero <= 1:
    return False
  # tentando iterar sobre uma sequencia e achar os numeros
  for i in range(2,numero):
    # tentando testar a divisão de todos os itens
    if numero % i == 0:
      return False # achou um divisor a mais
    # se testar todos e não achar o 0
    return True
primo = eh_primo(50)
print(primo) # se der certo eu verei os resultados

# %%
# tentando novamente criar um for para teste dos primos
for num in range(2, 51):
  if eh_primo(num): # reutilizando código
    print(f"O numero {num} é primo")

# %% [markdown]
# A saída foi satisfatória, porém o código está repetitivo e longo.
# Estudar formas de refatorar.

# %% [markdown]
# #Unid. 1_Aula 5 Encerramento

# %%
# preparando o protótipo da loja
# função criada pelo usuário
def calcular_desconto (valor, percentual):
  """Calcula o valor final aplicando um desconto percentual"""
  if percentual < 0 or percentual > 100:
    return None # marcação inválida
  desconto = valor * (percentual/100)
  return valor - desconto

def registrar_venda (produto, valor_final):
  """Imprime o registro de uma venda"""
  print(f">> Venda registrada: {produto} por R$ {valor_final: 2f}")

  # função lambida para arredondar
arrendondar = lambda v: round(v,2)

# %%
# Variaveis principais do PDV
total_vendas = 0
qtd_vendas = 0

# %%
#Loop principal do caixa MINHALOJAPDV
while True:
  print("\n----Minha Loja - PDV----")
  print("1 - Registrar venda")
  print("2 -  Ver relatório do dia")
  print("0 - Encerrar caixa")

  opcao = input("n\Digite opção desejada: ")
  if opcao == "0":
    print("Encerrar o caixa. Até amanhã!")
    break

  elif opcao == "1":
    produto = input("Nome do Produto: ")
    valor = float(input("Valor do Produto: R$ "))
    percentual = float(input("Desconto (%): "))

    valor_final = calcular_desconto(valor,percentual)

    if valor_final is None:
      print("Desconto inválido! Use um vaor entre 0 e 100")
    else:
      valor_final = arrendondar(valor_final)
      registrar_venda = (produto, valor_final)
      total_vendas = total_vendas+ valor_final
      qtd_vendas = qtd_vendas + 1

  elif opcao == "2":
    print(f"\nVendas de hoje: {qtd_vendas}")
    print(f"Total faturado: R$ {arrendondar(total_vendas)}")

  else:
    print("Opção inválida tente novamente.")
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# <>:8: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_1800/2753228038.py:8: SyntaxWarning: invalid escape sequence '\D'
#   opcao = input("n\Digite opção desejada: ")
# ----Minha Loja - PDV----
# 1 - Registrar venda
# 2 -  Ver relatório do dia
# 0 - Encerrar caixa
# n\Digite opção desejada: 1
# Nome do Produto: pão
# Valor do Produto: R$ 10
# Desconto (%): 5
# Desconto inválido! Use um vaor entre 0 e 100
#
# ----Minha Loja - PDV----
# 1 - Registrar venda
# 2 -  Ver relatório do dia
# 0 - Encerrar caixa
# n\Digite opção desejada: 1
# Nome do Produto: leite
# Valor do Produto: R$ 20
# Desconto (%): 10
# Desconto inválido! Use um vaor entre 0 e 100
#
# ----Minha Loja - PDV----
# 1 - Registrar venda
# 2 -  Ver relatório do dia
# 0 - Encerrar caixa
# n\Digite opção desejada: 2
# ---------------------------------------------------------------------------
# ...
