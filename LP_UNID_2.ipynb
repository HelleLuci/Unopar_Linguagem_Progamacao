# %% [markdown]
# <a href="https://colab.research.google.com/github/HelleLuci/Unopar_Linguagem_Progamacao/blob/main/LP_UNID_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unid. 2 _ Aula 1

# %%
texto = "Explorando a diversidade de linguagens de progaramação com Python"

# %%
print(f"Tamanho do texto= {len(texto)}")
# Out:
# Tamanho do texto: 65

# %%
print(f"Quantidade de letra 'a' no texto= {texto.count('a')}")
# Out:
# Quantidade de letra 'a' no texto= 7

# %%
print(f"As cinco primeiras letras são: {texto[:5]}")
# Out:
# As cinco primeiras letras são: Explo

# %%
cores = ["vermelho", "verde", "azul", "amarelo"]

# %%
for cor in cores:
  print(f"Posição= {cores.index(cor)}, cor = {cor}")
# Out:
# Posição= 0, cor = vermelho
# Posição= 1, cor = verde
# Posição= 2, cor = azul
# Posição= 3, cor = amarelo

# %%
linguagens = ["Python", "Java", "C#", "JavaScript"]

# %%
print("Antes da listcomprehension=", linguagens)
# Out:
# Antes da listcomprehension= ['Python', 'Java', 'C#', 'JavaScript']

# %%
linguagens = [item.lower() for item in linguagens]
print("\nDepois da listcomp=", linguagens)
# Out:
# Depois da listcomp= ['python', 'java', 'c#', 'javascript']

# %%
vogais = ("a","e", "i", "o", "u")

# %%
print(f"Tipos de objetos vogais = {type(vogais)}")
# Out:
# Tipos de objetos vogais = <class 'tuple'>

# %%
for p, x in enumerate(vogais):
  print(f"Posição = {p}, valor = {x}")
# Out:
# Posição = 0, valor = a
# Posição = 1, valor = e
# Posição = 2, valor = i
# Posição = 3, valor = o
# Posição = 4, valor = u

# %%
vogais = ("a","e", "i", "o", "u", "f")

# %%
print(vogais) #pesquisar porque foi poossivél mudar
"""Ele não modificou a original; ele criou uma nova tupla e jogou a antrior no lixo! Isso se repete na memória cada vez que rodamos a célula correspondente."""
# Out:
# ('a', 'e', 'i', 'o', 'u')

# %%
#desafio da lista de convidados
convidados = ("alice","rodrigo", "carol", "felipe")
confirmados = ["alice", "rodrigo"] #pode ser adicionado ou retirado

# %%
print("Convidados que ainda não confirmaram:")
for convidado in convidados:
  if convidado not in confirmados: #comparando as sequencias
    print(f"{convidado}")
# Out:
# Convidados que ainda não confirmaram:
# carol
# felipe

# %% [markdown]
# #Aula 2: Estruturas de Dados em Python parte 2

# %%
meu_conjunto = set()

# %%
meu_conjunto.add(10)
meu_conjunto.add(20)
meu_conjunto.add(30)

# %%
meu_conjunto.remove(20)

# %%
elemento = 20
if elemento in meu_conjunto:
  print(f"O elemento: {elemento}, está no conjunto.")
else:
  print(f"O elemento: {elemento}, não está no conjunto.")
# Out:
# O elemento: 20, não está no conjunto.

# %%
numeros_com_repeticao = [1,1,1,2,2,2,3,3,4,5,5,]

# %%
numeros_unicos = set(numeros_com_repeticao)

# %%
numeros_unicos
# Out:
# {1, 2, 3, 4, 5}

# %%
#criando dicionários
dic_1 = {}

# %%
dic_1['nome'] = "Maria"
dic_1['idade'] = 25

# %%
dic_1
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
#criando dicionário para exemplificar os métods de criação
dic_2 = {'nome': 'Maria', 'idade': 25}

# %%
dic_2
# Out:
# {'nome': 'Maria', 'idade': 25}

# %%
dic_3 = dict(nome = 'Maria', idade = 25)

# %%
dic_4 = dict(zip(['nome', 'idade'], ['Maria', 25]))

# %%
#acessando e alterando valores em um dicionário
produto = {'nome': 'Notebook', 'preco': 3500, 'estoque': 12}

print("Nome:", produto['nome'])
print("Preço:", produto['preco'])

#alterando valores
produto['estoque']= 10

#adicionando uma nova chave
produto['categoria'] = 'Informática'

print(produto)
# Out:
# Nome: Notebook
# Preço: 3500
# {'nome': 'Notebook', 'preco': 3500, 'estoque': 10, 'categoria': 'Informática'}

# %%
#NumPY_ Importando e criando um array
import numpy as np

my_array = np.array([1,2,3,4,5])
print("Array original: ")
print(my_array)

#operações em massa
squared_array = my_array ** 2 #cada elemento ao quadrado
sum_of_elemnts = np.sum(my_array) #soma de todos os elementos

print("\nArray ao quadrado:")
print(squared_array)
print("\nSoma array:")
print(sum_of_elemnts)
# Out:
# Array original:
# [1 2 3 4 5]
#
# Array ao quadrado:
# [ 1  4  9 16 25]
#
# Soma array:
# 15

# %%
#acessando um elemento pelo índice
print("Acessando elemento no índice 2: ", my_array[2])
# Out:
# Acessando elemento no índice 2:  3

# %%
#Desafio: Evento científico
"""Cada convidado é um dicionário mapping"""
participantes = [
    {'nome': 'Alice', 'localizacao':'Estado Unidos', 'afiliacao':'Universidade A' , 'interesses': ['Física', 'Astronomia']},
    {'nome': 'Anderson', 'localizacao':'Brasil', 'afiliacao':'Instituto B', 'interesses': ['Biologia', 'Astronomia']},
    {'nome':'Rajesh', 'localizacao': 'India', 'afiliacao':'Instituto C', 'interesses': ['Química', 'Engenharia']},
    {'nome': 'Vanessa', 'localizacao': 'Brasil', 'afiliacao': 'Universidade U', 'interesses': ['Tecnologia', 'Engenharia']}
]

#SET_Regiões dos participantes sem duplicar
regioes = set(p['localizacao'] for p in participantes)
#Dict_Agrupamento de participantes por afiliação
afiliacoes = {}
for p in participantes:
  aff= p['afiliacao']
  if aff not in afiliacoes:
    afiliacoes[aff] = []
  afiliacoes[aff].append(p['nome'])

#NumPy_Área de interesse mais popular
areas = np.array([i for p in participantes for i in p['interesses']])
unicos , contagem = np.unique(areas, return_counts= True)
mais_popular = unicos[np.argmax(contagem)]

#Resultados
print("Regiões dos participantes", regioes)
print("Afiliações dos participantes:")
for aff , nome in afiliacoes.items():
  print(f" {aff}: {','.join(nome)}")
print("Área de interesse mais popular: ", mais_popular)
"""Quando há um empate perfeito na contage, o interesse que aparece como 'mais popular' será sempre o que aparece prieiro na ordem alfabética, porque o np.unique ordena o texto e o np.argmax pega o primeiro que vê pela frente e ignora os outros"""
# Out:
# Regiões dos participantes {'Brasil', 'India', 'Estado Unidos'}
# Afiliações dos participantes:
#  Universidade A: Alice
#  Instituto B: Anderson
#  Instituto C: Rajesh
#  Universidade U: Vanessa
# Área de interesse mais popular:  Astronomia

# %% [markdown]
# #Aula 3_classes e métodos em Python

# %%
# Define uma classe chamada Pessoa. # rodado código exemplo na apostila

class Pessoa:

# O método __init__ é um construtor, chamado quando um objeto da classe é criado.

# Ele inicializa os atributos da classe.

  def __init__(self, nome, idade, genero):

    self.nome = nome

    self.idade = idade

    self.genero = genero

  def cumprimentar(self):

   return f"Olá, meu nome é {self.nome}."

# O método aniversário aumenta a idade da pessoa em 1.

  def aniversario(self):

    self.idade += 1

# %%
 # Cria uma instância da classe “Pessoa” com os valores “João”, 30 e “Masculino” para nome, idade e gênero, respectivamente.

pessoa1 = Pessoa("João", 30, "Masculino")

# Chama o método “cumprimentar” na instância pessoa1 e imprime a saudação.

print(pessoa1.cumprimentar())

# Acessa o atributo idade da instância pessoa1 e imprime sua idade.

print(f"Idade: {pessoa1.idade}")

# Chama o método “aniversário” na instância pessoa1 para aumentar sua idade em 1.

pessoa1.aniversario()

# Acessa o atributo idade atualizado da instância pessoa1 e imprime a nova idade.

print(f"Nova idade: {pessoa1.idade}")
# Out:
# Olá, meu nome é João.
# Idade: 30
# Nova idade: 31

# %%
#Trabalhando com Herança
class animal:
  def __init__(self, nome):
    self.nome = nome

  def fazer_barulho(self):
    pass #metodo vazio que será subescrito pelas classes filhas

# %%
class cachorro(animal):
    def fazer_barulho(self):
      return "Latir"

# %%
class  gato(animal):
    def fazer_barulho(self):
      return "Miar" #agora o gato sabe miar

# %%
#criando os objetos
rex = cachorro("Rex")
snowbell = gato("Snowbell")

# %%
print(f"{rex.nome} faz {rex.fazer_barulho()}")
print(f"{snowbell.nome} faz {snowbell.fazer_barulho()}")
# Out:
# Rex faz Latir
# Snowbell faz Miar

# %%
#exercício classe-veículo (classe-pai)
class Veiculo:

  def __init__(self, marca, modelo, ano):

    self.marca = marca

    self.modelo = modelo

    self.ano = ano

    self.velocidade = 0


  def acelerar(self, incremento):

    self.velocidade += incremento


  def frear(self, decremento):
    self.velocidade -= decremento
    if self.velocidade < 0:
        self.velocidade = 0  # Garante que o veículo não dê ré freando


  def status(self):

    return f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Velocidade: {self.velocidade} km/h"


class Carro(Veiculo): #classe filha 1

  def __init__(self, marca, modelo, ano, potencia):

    super().__init__(marca, modelo, ano)

    self.potencia = potencia #extensibilidade


  def acelerar(self, incremento):

# Carros podem acelerar mais rápido.

    self.velocidade += incremento + self.potencia


class Bicicleta(Veiculo):

  def __init__(self, marca, modelo, ano, tipo):

    super().__init__(marca, modelo, ano)

    self.tipo = tipo #mais extensibilidade


  def status(self):

    return f"Marca: {self.marca}, Modelo: {self.modelo}, Ano: {self.ano}, Tipo: {self.tipo}, Velocidade: {self.velocidade} km/h"


# Criando objetos após definir as classes

carro1 = Carro("Toyota", "Corolla", 2022, 150)

bicicleta1 = Bicicleta("Trek", "Mountain Bike", 2021, "MTB")

bicicleta2 = Bicicleta("Caloi", "Speed", 2008, "Estrada")


# Acelerando e verificando o status

carro1.acelerar(50)

bicicleta1.acelerar(20)

bicicleta2.acelerar(30)

# Exibindo o status dos veículos

print("Status do Carro:")

print(carro1.status())


print("\nStatus da Bicicleta:")

print(bicicleta1.status())
print(bicicleta2.status())
# Out:
# Status do Carro:
# Marca: Toyota, Modelo: Corolla, Ano: 2022, Velocidade: 200 km/h
#
# Status da Bicicleta:
# Marca: Trek, Modelo: Mountain Bike, Ano: 2021, Tipo: MTB, Velocidade: 20 km/h
# Marca: Caloi, Modelo: Speed, Ano: 2008, Tipo: Estrada, Velocidade: 30 km/h

# %%
carro1.frear(20)
print(carro1.status())
# Out:
# Marca: Toyota, Modelo: Corolla, Ano: 2022, Velocidade: 180 km/h

# %% [markdown]
# #Aula 4_Bibliotecas e módulos

# %%
#primeiro modo
import math


math.sqrt(25)

math.log2(1024)

math.cos(45)
# Out:
# 0.5253219888177297

# %%
#segundo modo
import math as m


m.sqrt(25)

m.log2(1024)

m.cos(45)
# Out:
# 0.5253219888177297

# %%
#segundo modo
import math as m


m.sqrt(25)

m.log2(1024)

m.cos(45)
# Out:
# 0.5253219888177297

# %%
import matplotlib.pyplot as plt


# Dados

x = [1, 2, 3, 4, 5]

y = [2, 4, 1, 3, 5]


# Criar um gráfico de linha

plt.plot(x, y)


# Adicionar rótulos aos eixos

plt.xlabel('Eixo X')

plt.ylabel('Eixo Y')


# Adicionar um título ao gráfico

plt.title('Exemplo de Gráfico de Linha')


# Mostrar o gráfico

plt.show()

# %%
import matplotlib.pyplot as plt


# Dados de exemplo

meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio']

vendas = [18, 90, 155, 5, 200]


# Criar um gráfico de barras

plt.bar(meses, vendas, color='gray')


# Adicionar rótulos aos eixos

plt.xlabel('Mês')

plt.ylabel('Vendas (em unidades)')


# Adicionar um título ao gráfico

plt.title('Vendas Mensais')


# Mostrar o gráfico

plt.show()

# %% [markdown]
# #Encerramento

# %%
import matplotlib.pyplot as plt

#criar clasee produto
class produto:
  def __init__ (self, nome, preco, categoria, estoque) :
    self.nome = nome
    self.preco = preco
    self.categoria = categoria
    self.estoque = estoque

  def __str__ (self):
    return (f"{self.nome} | R$ {self.preco} | "
            f"Categoria: {self.categoria} | Estoque: {self.estoque}")

# %%
catalogo = []
categorias = []

# %%
def adicionar_produto (nome, preco, categoria, estoque):
  novo_produto = produto (nome, preco, categoria, estoque)
  catalogo.append(novo_produto)
  categorias.append(categoria)
  print(f"Produto: '{nome}', adicionado a catálogo.")

# %%
def listar_catalogo():
  print("\n----Catálogo da Minha Loja----")
  for produto in catalogo:
    print(produto)

# %%
#cadastrar produtos
adicionar_produto('Notebook', 3500.00, 'Informática', 117)
adicionar_produto('Smartphone', 2200.00, 'Informática', 50)
adicionar_produto('Cadeira', 90.00, 'Móveis', 30)
adicionar_produto('Headphone', 120.00, 'Informática', 100)
adicionar_produto('Mouse', 45.00, 'Acessório', 30)

listar_catalogo()
# Out:
# Produto: 'Notebook', adicionado a catálogo.
# Produto: 'Smartphone', adicionado a catálogo.
# Produto: 'Cadeira', adicionado a catálogo.
# Produto: 'Headphone', adicionado a catálogo.
# Produto: 'Mouse', adicionado a catálogo.
#
# ----Catálogo da Minha Loja----
# Notebook | R$ 3500.0 | Categoria: Informática | Estoque: 117
# Smartphone | R$ 2200.0 | Categoria: Informática | Estoque: 50
# Cadeira | R$ 90.0 | Categoria: Móveis | Estoque: 30
# Headphone | R$ 120.0 | Categoria: Informática | Estoque: 100
# Mouse | R$ 45.0 | Categoria: Acessório | Estoque: 30

# %%
#grafico por categoria
categorias_unicas = list(set(categorias))
categorias_unicas.sort()

#contagem de produtos por categoria (lis comprehension)
contagem = [categorias.count(cat) for cat in categorias_unicas]

# %%
plt.bar(categorias_unicas, contagem, color = 'purple')
plt.xlabel('Categoria')
plt.ylabel('Número de Produtos')
plt.title('MinhaLoja Produtos por Categoria')

for i, valor in enumerate(contagem):
  plt.text(i, valor, str(valor), ha= 'center', va = 'bottom')
plt.grid(axis= 'y')
plt.show()
